# %%
import pandas_datareader as pdr
key="303b7da5dfa6612dd6342607c3cb2af7a7a384cb"
# Out:
# c:\Users\sajal\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.1.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
df = pdr.get_data_tiingo('BP', api_key=key)
df.to_csv('BP.csv')
# Out:
# c:\Users\sajal\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas_datareader\tiingo.py:234: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   return pd.concat(dfs, self._concat_axis)

# %%
import pandas as pd

# %%
df=pd.read_csv('BLK.csv')

# %%
df1=df.reset_index()['close']

# %%
import matplotlib.pyplot as plt
plt.plot(df1)
